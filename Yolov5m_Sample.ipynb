# %% [markdown]
# # Preparación del dataset para YOLOv5

# %%
import os
import pandas as pd
import shutil
from sklearn.model_selection import train_test_split

# 1. Rutas
image_base_path = '../data/processed/'   
csv_path = '../data/dataset.csv'      

# 2. Cargar y preparar datos
df = pd.read_csv(csv_path)
df = df[df["Bars"] >= 0].copy()
df["has_bar"] = df["Bars"].apply(lambda x: 1 if x > 0 else 0)
df["image_path"] = df["name"].apply(lambda x: os.path.join(image_base_path, f"{x}.png"))

# 3. Tomar muestra balanceada pequeña
sample_size = 1000  # por clase
sample_df = df.groupby("has_bar", group_keys=False).apply(lambda x: x.sample(n=sample_size, random_state=42))

# 4. División estratificada
train_df, val_df = train_test_split(sample_df, test_size=0.2, stratify=sample_df["has_bar"], random_state=42)

# 5. Crear carpetas destino
for subset in ['train', 'val']:
    os.makedirs(f'galaxy_yolo/images/{subset}', exist_ok=True)
    os.makedirs(f'galaxy_yolo/labels/{subset}', exist_ok=True)

# 6. Copiar imágenes y etiquetas
def process_subset(subset_df, subset_name):
    for _, row in subset_df.iterrows():
        img_name = os.path.basename(row['image_path'])
        image_dst = f'galaxy_yolo/images/{subset_name}/{img_name}'
        label_dst = f'galaxy_yolo/labels/{subset_name}/{os.path.splitext(img_name)[0]}.txt'

        shutil.copy(row['image_path'], image_dst)

        if row['has_bar'] == 1:
            with open(label_dst, 'w') as f:
                f.write('0 0.5 0.5 1.0 1.0\n')
        else:
            open(label_dst, 'w').close()

process_subset(train_df, 'train')
process_subset(val_df, 'val')

# 7. Crear archivo YAML
yaml_content = """train: galaxy_yolo/images/train
val: galaxy_yolo/images/val
nc: 1
names: ['bar']
"""
with open('galaxy_yolo/galaxy_dataset.yaml', 'w') as f:
    f.write(yaml_content)

# 8. Verificación
print("Dataset reducido preparado.")
print("Total muestras por clase:")
print(sample_df["has_bar"].value_counts())
print("\nTrain class distribution:")
print(train_df["has_bar"].value_counts())
print(train_df["has_bar"].value_counts(normalize=True))
print("\nVal class distribution:")
print(val_df["has_bar"].value_counts())
print(val_df["has_bar"].value_counts(normalize=True))
# Out:
# /var/folders/d2/x4hsqgc96j5gq48f813m7zq40000gn/T/ipykernel_50405/2332646923.py:18: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sample_df = df.groupby("has_bar", group_keys=False).apply(lambda x: x.sample(n=sample_size, random_state=42))
# Dataset reducido preparado.
# Total muestras por clase:
# has_bar
# 0    1000
# 1    1000
# Name: count, dtype: int64
#
# Train class distribution:
# has_bar
# 1    800
# 0    800
# Name: count, dtype: int64
# has_bar
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64
#
# Val class distribution:
# has_bar
# 0    200
# 1    200
# Name: count, dtype: int64
# has_bar
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17483, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 17483 (delta 80), reused 30 (delta 30), pack-reused 17373 (from 3)
# Receiving objects: 100% (17483/17483), 16.39 MiB | 2.71 MiB/s, done.
# Resolving deltas: 100% (11985/11985), done.

# %%
# !pip install -r yolov5/requirements.txt
# Out:
# Collecting gitpython>=3.1.30 (from -r yolov5/requirements.txt (line 5))
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: matplotlib>=3.3 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 6)) (3.10.3)
# Requirement already satisfied: numpy>=1.23.5 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 7)) (2.1.3)
# Collecting opencv-python>=4.1.1 (from -r yolov5/requirements.txt (line 8))
#   Using cached opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=10.3.0 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 9)) (11.2.1)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 10)) (7.0.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 13)) (1.15.3)
# Collecting thop>=0.1.1 (from -r yolov5/requirements.txt (line 14))
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.8.0 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 15)) (2.7.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 16)) (0.22.0)
# Collecting tqdm>=4.66.3 (from -r yolov5/requirements.txt (line 17))
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting ultralytics>=8.2.34 (from -r yolov5/requirements.txt (line 18))
#   Using cached ultralytics-8.3.141-py3-none-any.whl.metadata (37 kB)
# Collecting pandas>=1.1.4 (from -r yolov5/requirements.txt (line 27))
#   Downloading pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting seaborn>=0.11.0 (from -r yolov5/requirements.txt (line 28))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: setuptools>=70.0.0 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 42)) (78.1.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->-r yolov5/requirements.txt (line 5))
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r yolov5/requirements.txt (line 5))
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from requests>=2.32.2->-r yolov5/requirements.txt (line 12)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from requests>=2.32.2->-r yolov5/requirements.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from requests>=2.32.2->-r yolov5/requirements.txt (line 12)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from requests>=2.32.2->-r yolov5/requirements.txt (line 12)) (2025.4.26)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2025.5.0)
# Collecting py-cpuinfo (from ultralytics>=8.2.34->-r yolov5/requirements.txt (line 18))
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics>=8.2.34->-r yolov5/requirements.txt (line 18))
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Collecting pytz>=2020.1 (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27))
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27))
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.0.2)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Using cached opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl (37.3 MB)
# Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached ultralytics-8.3.141-py3-none-any.whl (1.0 MB)
# Downloading pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 2.4 MB/s eta 0:00:00a 0:00:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: pytz, py-cpuinfo, tzdata, tqdm, smmap, opencv-python, pandas, gitdb, ultralytics-thop, thop, seaborn, gitpython, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [ultralytics] [ultralytics]n]
# Successfully installed gitdb-4.0.12 gitpython-3.1.44 opencv-python-4.11.0.86 pandas-2.2.3 py-cpuinfo-9.0.0 pytz-2025.2 seaborn-0.13.2 smmap-5.0.2 thop-0.1.1.post2209072238 tqdm-4.67.1 tzdata-2025.2 ultralytics-8.3.141 ultralytics-thop-2.0.14

# %%
# !python yolov5/train.py \
  --img 416 \
  --batch 64 \
  --epochs 10 \
  --data galaxy_yolo/galaxy_dataset.yaml \
  --weights yolov5m.pt \
  --device cpu \
  --name bar_detector_sample \
  --cache
# Out:
# train: weights=yolov5m.pt, cfg=, data=galaxy_yolo/galaxy_dataset.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5/data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=cpu, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=bar_detector_sample, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-419-gcd44191c Python-3.10.16 torch-2.7.0 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     24246  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# Model summary: 291 layers, 20871318 parameters, 20871318 gradients, 48.2 GFLOPs
#
# Transferred 475/481 items from yolov5m.pt
# optimizer: SGD(lr=0.01) with parameter groups 79 weight(decay=0.0), 82 weight(decay=0.0005), 82 bias
# train: Scanning /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/iWARNING ⚠️ Error decoding JSON from /Users/isaidoropeza/Library/Application Support/Ultralytics/settings.json. Starting with an empty dictionary.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/isaidoropeza/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# train: Scanning /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/i
# train: New cache created: /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/galaxy_yolo/labels/train.cache
# train: Caching images (4.2GB ram): 100%|██████████| 8670/8670 [00:02<00:00, 4067
# val: Scanning /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/ite
# val: New cache created: /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/galaxy_yolo/labels/val.cache
# val: Caching images (1.8GB ram): 100%|██████████| 3780/3780 [00:00<00:00, 3895.5
#
# AutoAnchor: 2.00 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to yolov5/runs/train/bar_detector_sample/labels.jpg...
# /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 416 train, 416 val
# Using 8 dataloader workers
# Logging results to yolov5/runs/train/bar_detector_sample
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0%|          | 0/136 [00:00<?, ?it/s]/Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G     0.1212    0.01298          0         83        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G      0.123    0.01257          0         72        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G     0.1066    0.01251          0         74        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G      0.107    0.01271          0         81        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G     0.1093    0.01314          0         95        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G     0.1029    0.01321          0         81        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G      0.105    0.01322          0         80        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G     0.1009    0.01319          0         78        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09744    0.01323          0         85        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09803    0.01329          0         86        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09546    0.01327          0         76        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G     0.0974    0.01333          0         87        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09919    0.01328          0         76        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G     0.0999    0.01341          0         92        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09773    0.01341          0         75        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G     0.0984    0.01346          0         87        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09895    0.01355          0         87        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09697    0.01357          0         78        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09684    0.01366          0         89        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09685    0.01366          0         78        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09643    0.01369          0         84        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09473    0.01374          0         82        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09319     0.0137          0         66        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G     0.0917    0.01373          0         76        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09227    0.01376          0         80        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09095    0.01382          0         87        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09145    0.01386          0         81        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09116    0.01392          0         93        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09142    0.01396          0         85        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09122    0.01403          0         88        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09118    0.01405          0         80        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09009    0.01401          0         70        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09044    0.01402          0         74        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09055    0.01404          0         79        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09017    0.01407          0         82        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.08977    0.01404          0         69        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.09005    0.01407          0         80        416:  /Users/isaidoropeza/Documents/MNA_Proyecto_Integrador/Baseline/itesm-mna-barred-galaxies-main/notebooks/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         0/9         0G    0.